# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
import ast
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %%
#Downloading used nltk packages
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('words')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shrey\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Reading the data
df = pd.read_csv(r'D:\Customer Review Analysis Project\scraped_data.csv')

# %%
#Handling NaN Values by filling with custom values
df['Number of Reviews'][2] = "5"
df['Review Summary'][2] = "['Good Value for the Price','Reliable Performance','Impressive Battery Life','Sleek and Portable','Lacks High-End Features']"
df['Review Details'][2] = "[\"Been using it for several months, and it's dependable for my daily use. Multitasking is smooth, and it runs most of my applications without any hiccups.\", \"Battery lasts long enough for a full day's work without needing to plug in. It's perfect for long sessions at the cafe or library.\", \"I love the sleek design of this laptop. It's lightweight and easy to carry around, which is great for my on-the-go lifestyle.\", \"While it's a decent machine, it doesn't have the high-end features that I need for advanced gaming or video editing.\"]"

df['Number of Reviews'][5] = "8"
df['Review Summary'][5] = "['Sluggish and Unresponsive','Poor Screen Quality','Constant Overheating','Cheap Build Quality','Terrible Customer Service','Battery Drains Quickly','Decent for Basic Tasks','Affordable Entry-Level Option']"
df['Review Details'][5] ="[\"This laptop is frustratingly slow. It struggles with more than two applications open, making it nearly impossible to work efficiently.\", \"The display is dim and the colors are washed out. It's not a pleasant experience for watching videos or editing photos.\", \"It overheats within an hour of use, which is concerning. The fan noise is also quite loud and distracting.\", \"The materials feel cheap, and I'm worried about the durability of this laptop. The keyboard is particularly flimsy.\", \"Had an issue and contacted customer service, but the support was unhelpful and dismissive. Not impressed at all.\", \"The battery life is nowhere near what was advertised. It drains so fast that I'm always searching for an outlet.\", \"If all you need is something for basic web browsing and document editing, it gets the job done. Just don't expect much more.\", \"As an affordable entry-level laptop, it's an okay choice for those who are tech-savvy enough to manage its shortcomings.\"]"

# %%
#Dropping the products with no Ratings
dropped_df = df.dropna()

#Creating Lists of Strings
dropped_df.loc[:, 'Review Summary'] = dropped_df['Review Summary'].apply(ast.literal_eval)
dropped_df.loc[:, 'Review Details'] = dropped_df['Review Details'].apply(ast.literal_eval)

dropped_df = dropped_df.explode('Review Summary').reset_index(drop=True)

#Exploding the List for each product
df_summary_exploded = dropped_df['Review Summary'].explode('Review Summary').reset_index()
df_details_exploded = dropped_df['Review Details'].explode('Review Details').reset_index()

#Removing previous columns
dropped_df.drop('Review Summary', axis=1, inplace=True)
dropped_df.drop('Review Details', axis=1, inplace=True)

#Adding new splitted columns
dropped_df["Review Summary"] = df_summary_exploded["Review Summary"]
dropped_df["Review Details"] = df_details_exploded["Review Details"]

# Removing READ MORE from 'Review Details'
dropped_df['Review Details'] = dropped_df['Review Details'].str.replace("READ MORE", "", regex=False)

# %%
dropped_df.shape
# Out:
# (43, 7)

# %%
dropped_df
# Out:
#                                          Product Name      Price Rating  \
# 0   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 1   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 2   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 3   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 4   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 5   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 6   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 7   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990    4.3
# 8   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹47,990    3.7
# 9   Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990    4.6
# 10  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990    4.6
# 11  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990    4.6
# 12  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990    4.6
# 13  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990    4.6
# 14  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,24,990    4.3
# 15  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 16  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 17  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 18  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 19  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 20  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 21  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 22  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990    4.7
# 23  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 24  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 25  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 26  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 27  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 28  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 29  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 30  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 31  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 32  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990    4.4
# 33  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 34  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 35  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 36  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 37  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 38  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 39  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990    4.5
# 40  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,09,990    4.1
# 41  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,09,990    4.1
# 42  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,09,990    4.1
#
#    Number of Ratings Number of Reviews                 Review Summary  \
# 0                 68                 8                 Classy product
# 1                 68                 8                Worth the money
# 2                 68                 8                       Horrible
# 3                 68                 8            Best in the market!
# 4                 68                 8                         Super!
# 5                 68                 8                 Simply awesome
# 6                 68                 8                 Simply awesome
# 7                 68                 8                      Excellent
# 8                  7                 1    Battery issue, rest is good
# 9                  7                 5       Good Value for the Price
# 10                 7                 5           Reliable Performance
# 11                 7                 5        Impressive Battery Life
# 12                 7                 5             Sleek and Portable
# 13                 7                 5        Lacks High-End Features
# 14                25                 1                    Good choice
# 15                 3                 8      Sluggish and Unresponsive
# 16                 3                 8            Poor Screen Quality
# 17                 3                 8           Constant Overheating
# 18                 3                 8            Cheap Build Quality
# 19                 3                 8      Terrible Customer Service
# 20                 3                 8         Battery Drains Quickly
# 21                 3                 8         Decent for Basic Tasks
# 22                 3                 8  Affordable Entry-Level Option
# 23                88                18           Good quality product
# 24                88                18             Highly recommended
# 25                88                18              Worth every penny
# 26                88                18                 Classy product
# 27                88                18                      Very poor
# 28                88                18                    Good choice
# 29                88                18                      Wonderful
# 30                88                18                      Must buy!
# 31                88                18                     Delightful
# 32                88                18                    Really Nice
# 33                56                 7              Absolute rubbish!
# 34                56                 7          Mind-blowing purchase
# 35                56                 7                      Wonderful
# 36                56                 7      Did not meet expectations
# 37                56                 7                     Delightful
# 38                56                 7                        Awesome
# 39                56                 7                Worth the money
# 40                25                 3                      Wonderful
# 41                25                 3             Highly recommended
# 42                25                 3                      Must buy!
#
#                                        Review Details
# 0   First Impression: Great build no wobble, full ...
# 1   Overall the product is really nice. Lenovo has...
# 2   Lenovo worst company I purchased this laptop a...
# 3   great build and performance  of every segment ...
# 4   Bought it at 53k at sale. 16gb DDR5 Ram (dual ...
# 5   Good product and svperipherals  seller has giv...
# 6   It's performance is really good , but disappoi...
# 7   Awesome product and performs well to my expect...
# 8   First Impression: Great build no wobble, full ...
# 9   Overall the product is really nice. Lenovo has...
# 10  Lenovo worst company I purchased this laptop a...
# 11  great build and performance  of every segment ...
# 12  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...
# 13  Good product and svperipherals  seller has giv...
# 14  It's performance is really good , but disappoi...
# 15  Awesome product and performs well to my expect...
# 16  First Impression: Great build no wobble, full ...
# 17  Overall the product is really nice. Lenovo has...
# 18  Lenovo worst company I purchased this laptop a...
# 19  great build and performance  of every segment ...
# 20  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...
# 21  Good product and svperipherals  seller has giv...
# 22  It's performance is really good , but disappoi...
# 23  Awesome product and performs well to my expect...
# 24  First Impression: Great build no wobble, full ...
# 25  Overall the product is really nice. Lenovo has...
# 26  Lenovo worst company I purchased this laptop a...
# 27  great build and performance  of every segment ...
# 28  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...
# 29  Good product and svperipherals  seller has giv...
# 30  It's performance is really good , but disappoi...
# 31  Awesome product and performs well to my expect...
# 32  First Impression: Great build no wobble, full ...
# 33  Overall the product is really nice. Lenovo has...
# 34  Lenovo worst company I purchased this laptop a...
# 35  great build and performance  of every segment ...
# 36  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...
# 37  Good product and svperipherals  seller has giv...
# 38  It's performance is really good , but disappoi...
# 39  Awesome product and performs well to my expect...
# 40  First Impression: Great build no wobble, full ...
# 41  Overall the product is really nice. Lenovo has...
# 42  Lenovo worst company I purchased this laptop a...

# %% [markdown]
# ## NLTK

# %%
example = dropped_df['Review Details'][1]
example
# Out:
# 'Overall the product is really nice. Lenovo has included some tweaking features. The only problem that I felt is with the hinge. The laptop screen wobble sometimes.'

# %%
#Smartly Splits the text into parts so that the model can interpret it
tokens = nltk.word_tokenize(example)
tokens[:6]
# Out:
# ['Overall', 'the', 'product', 'is', 'really', 'nice']

# %%
#Part of speech tagging. Determines adjectives, nouns etc.
tagged = nltk.pos_tag(tokens)
tagged[:6]
# Out:
# [('Overall', 'JJ'),
#  ('the', 'DT'),
#  ('product', 'NN'),
#  ('is', 'VBZ'),
#  ('really', 'RB'),
#  ('nice', 'JJ')]

# %%
#Remove Stopwords such as 'The' 'is' 'and', etc.
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in tokens if word.lower() not in stop_words]
filtered_words
# Out:
# ['Overall',
#  'product',
#  'really',
#  'nice',
#  '.',
#  'Lenovo',
#  'included',
#  'tweaking',
#  'features',
#  '.',
#  'problem',
#  'felt',
#  'hinge',
#  '.',
#  'laptop',
#  'screen',
#  'wobble',
#  'sometimes',
#  '.']

# %%
dropped_df.to_csv('D:\Customer Review Analysis Project\preprocessed_data.csv', index=False)
