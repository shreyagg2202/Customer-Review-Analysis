# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
df = pd.read_csv(r"D:\Customer Review Analysis Project\preprocessed_data.csv")
df.head()
# Out:
#                                         Product Name    Price  Rating  \
# 0  Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...  ₹56,990     4.3
# 1  Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...  ₹56,990     4.3
# 2  Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...  ₹56,990     4.3
# 3  Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...  ₹56,990     4.3
# 4  Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...  ₹56,990     4.3
#
#    Number of Ratings  Number of Reviews       Review Summary  \
# 0                 68                  8       Classy product
# 1                 68                  8      Worth the money
# 2                 68                  8             Horrible
# 3                 68                  8  Best in the market!
# 4                 68                  8               Super!
#
#                                       Review Details
# 0  First Impression: Great build no wobble, full ...
# 1  Overall the product is really nice. Lenovo has...
# 2  Lenovo worst company I purchased this laptop a...
# 3  great build and performance  of every segment ...
# 4  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...

# %%
def calculate_weighted_score(row, model):

    #Normalizing the ratings and number of reviews
    normalized_rating = row['Rating']/5
    normalized_number_of_reviews = row["Number of Reviews"]/10

    #Calculate sentiment scores for review summary and detailsthe ratings and number of reviews
    review_summary_score = model(row['Review Summary'])
    review_details_score = model(row['Review Details'])

    #Review summary sentiment scores
    review_summary_negative_val = review_summary_score['neg']
    review_summary_neutral_val = review_summary_score['neu']
    review_summary_positive_val = review_summary_score['pos']
    review_summary_compound_val = review_summary_score['compound']

    #Review details sentiment scores
    review_details_negative_val = review_details_score['neg']
    review_details_neutral_val = review_details_score['neu']
    review_details_positive_val = review_details_score['pos']
    review_details_compound_val = review_details_score['compound']
    
    # print("Product Name: ", row["Product Name"])
    # print("Normalized Rating: ", normalized_rating)
    # print("Normalized number of reviews: ", normalized_rating)
    # print(row['Review Summary'])
    # print("Summary Review Score: ", review_summary_score)
    # print(row['Review Details'])
    # print("Summary Details Score: ", review_details_score)
    # print("-" *50)
    
    #Initializing weights based on imporance of features
    weights = {"Rating" : 0.2, "Review Summary" : 0.3, "Review Details" : 0.5}

    #Weighted score calculations
    weighted_negative_score = (review_summary_negative_val * weights["Review Summary"] + review_details_negative_val * weights["Review Details"])
    weighted_neutral_score = (review_summary_neutral_val * weights["Review Summary"] + review_details_neutral_val * weights["Review Details"])
    weighted_positive_score = (review_summary_positive_val * weights["Review Summary"] + review_details_positive_val * weights["Review Details"])
    
    weighted_compound_score = (normalized_rating * weights["Rating"] +
                      review_summary_compound_val * weights["Review Summary"] +
                      review_details_compound_val * weights["Review Details"])
    
    return weighted_negative_score, weighted_neutral_score, weighted_positive_score, weighted_compound_score

# %% [markdown]
# # VADER Sentiment Analysis

# %%
#Loading the VADER model
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("The laptop is really good and has a lot of cool and latest features")
# Out:
# {'neg': 0.0, 'neu': 0.667, 'pos': 0.333, 'compound': 0.6697}

# %%
print(df['Review Details'][1])
sia.polarity_scores(df['Review Details'][1])
# Out:
# Overall the product is really nice. Lenovo has included some tweaking features. The only problem that I felt is with the hinge. The laptop screen wobble sometimes.
# {'neg': 0.091, 'neu': 0.806, 'pos': 0.104, 'compound': 0.101}

# %%
#Calculates the VADER score for some 'text'
def calculate_vader_score (text):
    return sia.polarity_scores(text)

# %%
#Run the polarity score on the entire dataset and create columns for it
df[['VADER_neg','VADER_neu','VADER_pos','VADER_compound_score']] = df.apply(calculate_weighted_score, args=(calculate_vader_score,), axis = 1,result_type='expand')

# %%
#Box Plot of VADER compound scores
plt.figure(figsize=(12, 8))  
sns.boxplot(x='VADER_compound_score', y='Product Name', data=df)  
plt.title('Box Plot of VADER Scores by Product')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # ROBERTA Sentiment Analysis

# %%
#Loading the RoBERTa model
MODEL = "cardiffnlp/twitter-roberta-base-sentiment-latest"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
print(df['Review Details'][1])
sia.polarity_scores(df['Review Details'][1])
# Out:
# Overall the product is really nice. Lenovo has included some tweaking features. The only problem that I felt is with the hinge. The laptop screen wobble sometimes.
# {'neg': 0.091, 'neu': 0.806, 'pos': 0.104, 'compound': 0.101}

# %%
print(df['Review Details'][1])
encoded_text = tokenizer(df['Review Details'][1], return_tensors='pt')             
output = model(**encoded_text)                                                     
scores = output[0][0].detach().numpy()                                             
scores = softmax(scores)
# Out:
# Overall the product is really nice. Lenovo has included some tweaking features. The only problem that I felt is with the hinge. The laptop screen wobble sometimes.

# %%
encoded_text = tokenizer("The laptop is really good and has a lot of cool and latest features", return_tensors='pt')
output = model(**encoded_text)
scores = output[0][0].detach().numpy()
scores = softmax(scores)

# %%
def calculate_roberta_score(text):
    encoded_text = tokenizer(text, return_tensors='pt')                             #Tokenization
    output = model(**encoded_text)                                                  #model input
    scores = output[0][0].detach().numpy()                                          #post processing
    scores = softmax(scores)

    negative_score = scores[0]
    neutral_score = scores[1]
    positive_score = scores[2]
    
    # Calculating compound score based on negative, neutral and positive scores
    compound_score = (negative_score * -1) + (neutral_score * 0) + (positive_score * 1)

    scores_dict = {
        "neg" : scores[0],
        "neu" : scores[1],
        "pos" : scores[2],
        "compound" : compound_score
    }
    # print(scores_dict)
    
    return scores_dict

# %%
#Run the roBERTa model on the entire dataset and create columns for it
df[['RoBERTa_neg','RoBERTa_neu','RoBERTa_pos','RoBERTa_compound_Score']] = df.apply(calculate_weighted_score, args=(calculate_roberta_score,), axis = 1,result_type='expand')

# %%
df
# Out:
#                                          Product Name      Price  Rating  \
# 0   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 1   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 2   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 3   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 4   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 5   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 6   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 7   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹56,990     4.3
# 8   Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core ...    ₹47,990     3.7
# 9   Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990     4.6
# 10  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990     4.6
# 11  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990     4.6
# 12  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990     4.6
# 13  Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - ...    ₹99,990     4.6
# 14  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,24,990     4.3
# 15  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 16  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 17  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 18  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 19  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 20  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 21  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 22  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,19,990     4.7
# 23  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 24  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 25  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 26  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 27  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 28  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 29  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 30  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 31  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 32  Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800...    ₹98,990     4.4
# 33  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 34  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 35  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 36  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 37  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 38  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 39  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800...  ₹1,04,990     4.5
# 40  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,09,990     4.1
# 41  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,09,990     4.1
# 42  Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800...  ₹1,09,990     4.1
#
#     Number of Ratings  Number of Reviews                 Review Summary  \
# 0                  68                  8                 Classy product
# 1                  68                  8                Worth the money
# 2                  68                  8                       Horrible
# 3                  68                  8            Best in the market!
# 4                  68                  8                         Super!
# 5                  68                  8                 Simply awesome
# 6                  68                  8                 Simply awesome
# 7                  68                  8                      Excellent
# 8                   7                  1    Battery issue, rest is good
# 9                   7                  5       Good Value for the Price
# 10                  7                  5           Reliable Performance
# 11                  7                  5        Impressive Battery Life
# 12                  7                  5             Sleek and Portable
# 13                  7                  5        Lacks High-End Features
# 14                 25                  1                    Good choice
# 15                  3                  8      Sluggish and Unresponsive
# 16                  3                  8            Poor Screen Quality
# 17                  3                  8           Constant Overheating
# 18                  3                  8            Cheap Build Quality
# 19                  3                  8      Terrible Customer Service
# 20                  3                  8         Battery Drains Quickly
# 21                  3                  8         Decent for Basic Tasks
# 22                  3                  8  Affordable Entry-Level Option
# 23                 88                 18           Good quality product
# 24                 88                 18             Highly recommended
# 25                 88                 18              Worth every penny
# 26                 88                 18                 Classy product
# 27                 88                 18                      Very poor
# 28                 88                 18                    Good choice
# 29                 88                 18                      Wonderful
# 30                 88                 18                      Must buy!
# 31                 88                 18                     Delightful
# 32                 88                 18                    Really Nice
# 33                 56                  7              Absolute rubbish!
# 34                 56                  7          Mind-blowing purchase
# 35                 56                  7                      Wonderful
# 36                 56                  7      Did not meet expectations
# 37                 56                  7                     Delightful
# 38                 56                  7                        Awesome
# 39                 56                  7                Worth the money
# 40                 25                  3                      Wonderful
# 41                 25                  3             Highly recommended
# 42                 25                  3                      Must buy!
#
#                                        Review Details  VADER_neg  VADER_neu  \
# 0   First Impression: Great build no wobble, full ...     0.0390     0.4588
# 1   Overall the product is really nice. Lenovo has...     0.0455     0.5569
# 2   Lenovo worst company I purchased this laptop a...     0.4085     0.3250
# 3   great build and performance  of every segment ...     0.0000     0.5060
# 4   Bought it at 53k at sale. 16gb DDR5 Ram (dual ...     0.0000     0.5000
# 5   Good product and svperipherals  seller has giv...     0.0000     0.4258
# 6   It's performance is really good , but disappoi...     0.0845     0.3558
# 7   Awesome product and performs well to my expect...     0.0000     0.4035
# 8   First Impression: Great build no wobble, full ...     0.0390     0.5560
# 9   Overall the product is really nice. Lenovo has...     0.0455     0.5113
# 10  Lenovo worst company I purchased this laptop a...     0.1085     0.6250
# 11  great build and performance  of every segment ...     0.0000     0.4991
# 12  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...     0.0000     0.8000
# 13  Good product and svperipherals  seller has giv...     0.0000     0.6670
# 14  It's performance is really good , but disappoi...     0.0845     0.3738
# 15  Awesome product and performs well to my expect...     0.1722     0.5313
# 16  First Impression: Great build no wobble, full ...     0.2214     0.4996
# 17  Overall the product is really nice. Lenovo has...     0.0455     0.7030
# 18  Lenovo worst company I purchased this laptop a...     0.1085     0.6250
# 19  great build and performance  of every segment ...     0.1824     0.5036
# 20  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...     0.0000     0.8000
# 21  Good product and svperipherals  seller has giv...     0.0000     0.6670
# 22  It's performance is really good , but disappoi...     0.0845     0.5970
# 23  Awesome product and performs well to my expect...     0.0000     0.5259
# 24  First Impression: Great build no wobble, full ...     0.0390     0.4789
# 25  Overall the product is really nice. Lenovo has...     0.0455     0.5569
# 26  Lenovo worst company I purchased this laptop a...     0.1085     0.4018
# 27  great build and performance  of every segment ...     0.2316     0.4544
# 28  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...     0.0000     0.5768
# 29  Good product and svperipherals  seller has giv...     0.0000     0.3670
# 30  It's performance is really good , but disappoi...     0.0845     0.5970
# 31  Awesome product and performs well to my expect...     0.0000     0.4035
# 32  First Impression: Great build no wobble, full ...     0.0390     0.4552
# 33  Overall the product is really nice. Lenovo has...     0.0455     0.7030
# 34  Lenovo worst company I purchased this laptop a...     0.1085     0.6250
# 35  great build and performance  of every segment ...     0.0000     0.3860
# 36  Bought it at 53k at sale. 16gb DDR5 Ram (dual ...     0.0000     0.8000
# 37  Good product and svperipherals  seller has giv...     0.0000     0.3670
# 38  It's performance is really good , but disappoi...     0.0845     0.2970
# 39  Awesome product and performs well to my expect...     0.0000     0.5574
# 40  First Impression: Great build no wobble, full ...     0.0390     0.3820
# 41  Overall the product is really nice. Lenovo has...     0.0455     0.4999
# 42  Lenovo worst company I purchased this laptop a...     0.1085     0.6250
#
#     VADER_pos  VADER_compound_score  RoBERTa_neg  RoBERTa_neu  RoBERTa_pos  \
# 0      0.3022               0.63937     0.017888     0.098062     0.684050
# 1      0.1981               0.29039     0.019649     0.095335     0.685016
# 2      0.0665              -0.23024     0.689685     0.084033     0.026282
# 3      0.2940               0.72768     0.003588     0.023521     0.772890
# 4      0.3000               0.36280     0.014775     0.228311     0.556914
# 5      0.3742               0.57967     0.011333     0.045562     0.743104
# 6      0.3597               0.46552     0.014475     0.046320     0.739206
# 7      0.3965               0.71112     0.041478     0.107210     0.651312
# 8      0.2050               0.61537     0.030847     0.174560     0.594594
# 9      0.2437               0.42908     0.020192     0.129646     0.650162
# 10     0.0665              -0.05555     0.486174     0.166514     0.147312
# 11     0.3009               0.69198     0.005055     0.022554     0.772391
# 12     0.0000               0.18400     0.023274     0.422621     0.354105
# 13     0.1330               0.40420     0.231839     0.102031     0.466130
# 14     0.3417               0.41017     0.019210     0.085054     0.695736
# 15     0.0965               0.43498     0.279334     0.109032     0.411634
# 16     0.0790               0.38024     0.253516     0.082719     0.463766
# 17     0.0520               0.23850     0.084792     0.256315     0.458893
# 18     0.0665              -0.05155     0.504630     0.193072     0.102298
# 19     0.1140               0.39979     0.278711     0.031726     0.489563
# 20     0.0000               0.18800     0.017113     0.416996     0.365891
# 21     0.1330               0.40820     0.024617     0.198506     0.576876
# 22     0.1185               0.29405     0.018336     0.274450     0.507214
# 23     0.2741               0.67567     0.036271     0.090723     0.673006
# 24     0.2821               0.59273     0.013371     0.049091     0.737538
# 25     0.1981               0.29439     0.018519     0.076608     0.704872
# 26     0.2897               0.06857     0.484514     0.083971     0.231515
# 27     0.1140               0.37312     0.247839     0.058612     0.493549
# 28     0.2232               0.30812     0.022550     0.260198     0.517252
# 29     0.4330               0.56777     0.009333     0.049142     0.741525
# 30     0.1185               0.28205     0.011781     0.058957     0.729262
# 31     0.3965               0.71932     0.033350     0.079102     0.687549
# 32     0.3058               0.65387     0.014333     0.053219     0.732448
# 33     0.0520               0.23050     0.270303     0.092551     0.437146
# 34     0.0665              -0.05955     0.505095     0.096217     0.198688
# 35     0.4140               0.70637     0.005507     0.028670     0.765824
# 36     0.0000               0.18000     0.183034     0.305395     0.311571
# 37     0.4330               0.57597     0.008170     0.049039     0.742791
# 38     0.4185               0.47352     0.013816     0.055469     0.730715
# 39     0.2426               0.61544     0.034686     0.101039     0.664275
# 40     0.3790               0.67082     0.012407     0.051784     0.735810
# 41     0.2551               0.29598     0.020440     0.070809     0.708751
# 42     0.0665              -0.07555     0.478339     0.046751     0.274910
#
#     RoBERTa_compound_Score
# 0                 0.838162
# 1                 0.837367
# 2                -0.491403
# 3                 0.941302
# 4                 0.714139
# 5                 0.903771
# 6                 0.896731
# 7                 0.781834
# 8                 0.711747
# 9                 0.813970
# 10               -0.154863
# 11                0.951336
# 12                0.514831
# 13                0.418291
# 14                0.848527
# 15                0.320300
# 16                0.398250
# 17                0.562101
# 18               -0.214333
# 19                0.398853
# 20                0.536778
# 21                0.740259
# 22                0.676877
# 23                0.812736
# 24                0.900167
# 25                0.862353
# 26               -0.076999
# 27                0.421710
# 28                0.670702
# 29                0.908192
# 30                0.893481
# 31                0.830199
# 32                0.894114
# 33                0.346842
# 34               -0.126408
# 35                0.940317
# 36                0.308538
# 37                0.914622
# 38                0.896899
# 39                0.809589
# 40                0.887403
# 41                0.852312
# 42               -0.039429

# %%
#Box Plot of RoBERTa compound scores
plt.figure(figsize=(12, 8))
sns.boxplot(x='RoBERTa_compound_Score', y='Product Name', data=df)
plt.title('Box Plot of RoBERTa Scores by Product')
plt.xticks(rotation=45)
plt.show()

# %%
df.columns
# Out:
# Index(['Product Name', 'Price', 'Rating', 'Number of Ratings',
#        'Number of Reviews', 'Review Summary', 'Review Details', 'VADER_neg',
#        'VADER_neu', 'VADER_pos', 'VADER_compound_score', 'RoBERTa_neg',
#        'RoBERTa_neu', 'RoBERTa_pos', 'RoBERTa_compound_Score'],
#       dtype='object')

# %%
#Correlation analyses on VADER and RoBERTa scores
sns.pairplot(data=df,
             vars=['VADER_neg','VADER_neu', 'VADER_pos',
                  'RoBERTa_neg','RoBERTa_neu', 'RoBERTa_pos'])
# Out:
# C:\Users\shrey\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shrey\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shrey\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shrey\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shrey\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\shrey\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#agrregating scores by grouping reviews for each product
aggregate_scores = df.groupby('Product Name').agg({
    'VADER_compound_score': 'mean',  # or any other aggregation method
    'RoBERTa_compound_Score': 'mean'
})

# %%
aggregate_scores
# Out:
#                                                     VADER_compound_score  \
# Product Name
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 5...              0.615370
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 7...              0.443289
# Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800H...              0.453561
# Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - (...              0.330742
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...              0.388893
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...              0.286526
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...              0.297083
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...              0.410170
#
#                                                     RoBERTa_compound_Score
# Product Name
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 5...                0.711747
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 7...                0.677738
# Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800H...                0.711665
# Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - (...                0.508713
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...                0.584343
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...                0.427386
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...                0.566762
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...                0.848527

# %%
#Avergae score for each product based on both model results
aggregate_scores['Combined_Score'] = aggregate_scores.mean(axis=1)

# %%
aggregate_scores
# Out:
#                                                     VADER_compound_score  \
# Product Name
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 5...              0.615370
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 7...              0.443289
# Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800H...              0.453561
# Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - (...              0.330742
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...              0.388893
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...              0.286526
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...              0.297083
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...              0.410170
#
#                                                     RoBERTa_compound_Score  \
# Product Name
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 5...                0.711747
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 7...                0.677738
# Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800H...                0.711665
# Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - (...                0.508713
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...                0.584343
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...                0.427386
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...                0.566762
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...                0.848527
#
#                                                     Combined_Score
# Product Name
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 5...        0.663558
# Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 7...        0.560513
# Lenovo Legion 5 AMD AMD Ryzen 7 Octa Core 5800H...        0.582613
# Lenovo Legion 5 AMD Ryzen 7 Octa Core 5800H - (...        0.419728
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...        0.486618
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 5800H...        0.356956
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...        0.431923
# Lenovo Legion 5 Pro AMD Ryzen 7 Octa Core 6800H...        0.629348

# %%
#Finding the BEST PRODUCT
best_product = aggregate_scores['Combined_Score'].idxmax()
print("Product with the highest combined score:" ,best_product)
# Out:
# Product with the highest combined score: Lenovo IdeaPad Gaming 3 AMD Ryzen 5 Hexa Core 5500H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/N...
